# %%
import pandas as pd
from pymongo import MongoClient

# %%
def pipeline(news_source):
    client = MongoClient()
    db = client[f'{news_source}']
    articles = db['articles']
    df = pd.DataFrame(list(articles.find()))
    df = df.iloc[:,1:]
    df = df.drop_duplicates()
    df['source']=f'{news_source}'
    return df

# %%
pipeline('breitbart')
# Out:
#                                                   title           author  \
# 0     AOC: Tara Reade’s Sexual Assault Allegation Ag...      Penny Starr
# 1     GOP Lawmakers: Halt Visas to Foreign Workers W...      John Binder
# 2     Chris Christie Slams Obama DOJ After Supreme C...   Joel B. Pollak
# 3     Yale Scientist: Reopening America Is ‘Awfully ...     Tom Ciccotta
# 4     Schumer: Trump, McCarthy, McConnell ‘Remind Me...      Trent Baker
# ...                                                 ...              ...
# 3431  Fights, Thefts, Arguments as Toilet Paper Mani...       Kyle Olson
# 3432  Coronavirus: Ventilator Manufacturers Not Ramp...   Joel B. Pollak
# 3433  WHO: Europe Has Become ‘Epicenter’ of Coronavi...  Dr. Susan Berry
# 3434  ‘Outrageous:’ Senate Dems Block Bill to Addres...       Edwin Mora
# 3435  CNN’s Jim Acosta: Trump is ‘The Take-No-Respon...    Joshua Caplan
#
#              date                                            content  \
# 0      7 May 2020  Rep. Alexandria Ocasio-Cortez (D-NY) said in a...
# 1      7 May 2020  A coalition of Republican senators and congres...
# 2      7 May 2020  Former New Jersey Gov. Chris Christie slammed ...
# 3      7 May 2020  A Yale University scientist argued in a social...
# 4      7 May 2020  In a Thursday appearance on MSNBC, Senate Mino...
# ...           ...                                                ...
# 3431  13 Mar 2020  Society is seemingly melting down all around u...
# 3432  13 Mar 2020  American companies that manufacture ventilator...
# 3433  13 Mar 2020  The World Health Organization (WHO) declared o...
# 3434  13 Mar 2020  Senate Democrats on Thursday obstructed the pa...
# 3435  13 Mar 2020  CNN chief White House correspondent Jim Acosta...
#
#          source
# 0     breitbart
# 1     breitbart
# 2     breitbart
# 3     breitbart
# 4     breitbart
# ...         ...
# 3431  breitbart
# 3432  breitbart
# 3433  breitbart
# 3434  breitbart
# 3435  breitbart
#
# [3192 rows x 5 columns]

# %%
pipeline('occupy_democrats')
# Out:
#                                                   title             author  \
# 0     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tHistor...       Colin Taylor
# 1     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tGovern...       Colin Taylor
# 2     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDue to...       Colin Taylor
# 3     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCostco...       Colin Taylor
# 4     Historic Win For Progressives as Boy Scouts Li...       Colin Taylor
# ...                                                 ...                ...
# 2482  “You & Trump Can Go To Hell!” A Principal Just...  Brian Tyler Cohen
# 2483   Trump Just Launched His Attack On Marijuana Laws  Brian Tyler Cohen
# 2484  The Pope Just Gave Trump The Mother Of All Sco...      Peter Mellado
# 2485  The Kushner Family Just Booted Reporters Out O...       Colin Taylor
# 2486  A Dem Just Found The Best Solution For Republi...  Brian Tyler Cohen
#
#                 date                                            content  \
# 0     April 19, 2013  In a historic victory for gay and human rights...
# 1     April 20, 2013  Just as America thought Texan Republicans had ...
# 2     April 21, 2013  An American Al Qaeda spokesman says it’s so ea...
# 3     April 22, 2013  It’s official, paying decent wages and treatin...
# 4     April 19, 2013  In a historic victory for gay and human rights...
# ...              ...                                                ...
# 2482     May 6, 2017  Two teenagers make the ill-advised decision to...
# 2483     May 6, 2017  Marijuana advocates had plenty to cheer about ...
# 2484     May 6, 2017  Donald Trump has ordered two high profile mili...
# 2485     May 6, 2017  The Trump family’s relentless efforts to use t...
# 2486     May 6, 2017  On the heels of their controversial vote to re...
#
#                 source
# 0     occupy_democrats
# 1     occupy_democrats
# 2     occupy_democrats
# 3     occupy_democrats
# 4     occupy_democrats
# ...                ...
# 2482  occupy_democrats
# 2483  occupy_democrats
# 2484  occupy_democrats
# 2485  occupy_democrats
# 2486  occupy_democrats
#
# [2481 rows x 5 columns]
