# %%
# %matplotlib inline
from data_pipline_and_eda_helper_class import *

# %%
data_pipeline = DataPipeline()

# %%
data_pipeline.combine_news_sources('occupy_democrats','breitbart')

# %%
data_pipeline.plot_word_counts()

# %%
data_pipeline.plot_top_ten_authors('breitbart','r')
# Out:
# author            source
# Charlie Spiering  breitbart    471
# Hannah Bleau      breitbart    439
# Joshua Caplan     breitbart    338
# Pam Key           breitbart    337
# Ian Hanchett      breitbart    263
# Joel B. Pollak    breitbart    218
# John Binder       breitbart    212
# Trent Baker       breitbart    181
# Penny Starr       breitbart    172
# Sean Moran        breitbart    167
# Name: title, dtype: int64

# %%
data_pipeline.plot_top_ten_authors('occupy_democrats','b')
# Out:
# author             source
# Colin Taylor       occupy_democrats    1026
# Natalie Dickinson  occupy_democrats     834
# Vinnie Longobardo  occupy_democrats     695
# Grant Stern        occupy_democrats     604
# Brian Tyler Cohen  occupy_democrats     461
# Sheila Norton      occupy_democrats     397
# Rob Haffey         occupy_democrats     379
# Marisa Manfredo    occupy_democrats     261
# Peter Mellado      occupy_democrats     205
# Benjamin Locke     occupy_democrats     203
# Name: title, dtype: int64

# %%
df = data_pipeline.articles_info

# %%
len(df['author'][df['source']=='breitbart'].unique())
# Out:
# 95

# %%
len(df['author'][df['source']=='occupy_democrats'].unique())
# Out:
# 26

# %%
data_pipeline.plot_article_dates()
# Out:
# /Users/femikalejaiye/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
df['year']= [i.year for i in df['date']]
df['month']= [i.month for i in df['date']]

# %%
df
# Out:
#                                                    title            author  \
# 0      Historic Win For Progressives as Boy Scouts Li...      Colin Taylor
# 1      Governor Perry and Texan Republicans Hypocriti...      Colin Taylor
# 2      Due to Weak American Gun Control Laws, Al Qued...      Colin Taylor
# 3      Costco Pays Well and Soars, While Wal-Mart and...      Colin Taylor
# 4      New Study Finds That Supporters of Reaganomics...      Colin Taylor
# ...                                                  ...               ...
# 11287  Coronavirus Could Tip the Scales As Poll Shows...     Deborah Danan
# 11288  Sweden: Populists Lead in Polls, Social Democr...   Chris Tomlinson
# 11289  France Bans Mass Gatherings to Stave Off Coron...  Breitbart London
# 11290  Obama’s Body Man Reggie Love Rallies Pete Butt...  Charlie Spiering
# 11291  CDC Disease Director: Low Number of U.S. Coron...   Dr. Susan Berry
#
#             date                                            content  \
# 0     2013-04-19  In a historic victory for gay and human rights...
# 1     2013-04-20  Just as America thought Texan Republicans had ...
# 2     2013-04-21  An American Al Qaeda spokesman says it’s so ea...
# 3     2013-04-22  It’s official, paying decent wages and treatin...
# 4     2013-04-22  According to a new study by Psychological Scie...
# ...          ...                                                ...
# 11287 2020-03-01  TEL AVIV – Coronavirus could prove to be the w...
# 11288 2020-03-01  Sweden’s ruling Social Democrats saw their wor...
# 11289 2020-03-01  (AFP) — France on Saturday cancelled all gathe...
# 11290 2020-03-01  Former President Barack Obama’s body man Reggi...
# 11291 2020-03-01  The still low number of cases of the novel cor...
#
#                  source  year  month
# 0      occupy_democrats  2013      4
# 1      occupy_democrats  2013      4
# 2      occupy_democrats  2013      4
# 3      occupy_democrats  2013      4
# 4      occupy_democrats  2013      4
# ...                 ...   ...    ...
# 11287         breitbart  2020      3
# 11288         breitbart  2020      3
# 11289         breitbart  2020      3
# 11290         breitbart  2020      3
# 11291         breitbart  2020      3
#
# [11292 rows x 7 columns]

# %%
df[df['source']=='occupy_democrats'].groupby(['year','month']).count()['title']
# Out:
# year  month
# 2013  4          5
# 2016  6         24
#       7        146
#       8        162
#       9        214
#       10       288
#       11       248
#       12       191
# 2017  1        261
#       2        318
#       3        490
#       4        515
#       5        543
#       6        231
#       7         20
#       8        264
#       9        405
#       10         2
# 2018  3          1
#       7          1
# 2019  6         15
#       7          1
#       8         33
#       9        169
#       10       197
#       11       153
#       12       143
# 2020  1        178
#       2        144
#       3        147
#       4        103
#       5         27
# Name: title, dtype: int64
