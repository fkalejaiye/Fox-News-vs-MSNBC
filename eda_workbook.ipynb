# %%
# %matplotlib inline
from data_pipline_and_eda_helper_class import *

# %%
data_pipeline = DataPipeline()

# %%
data_pipeline.combine_news_sources('occupy_democrats','breitbart')
# Out:
#                                                   title            author  \
# 0     Historic Win For Progressives as Boy Scouts Li...      Colin Taylor
# 1     Governor Perry and Texan Republicans Hypocriti...      Colin Taylor
# 2     Due to Weak American Gun Control Laws, Al Qued...      Colin Taylor
# 3     Costco Pays Well and Soars, While Wal-Mart and...      Colin Taylor
# 4     New Study Finds That Supporters of Reaganomics...      Colin Taylor
# ...                                                 ...               ...
# 5648  Coronavirus Could Tip the Scales As Poll Shows...     Deborah Danan
# 5649  Sweden: Populists Lead in Polls, Social Democr...   Chris Tomlinson
# 5650  France Bans Mass Gatherings to Stave Off Coron...  Breitbart London
# 5651  Obama’s Body Man Reggie Love Rallies Pete Butt...  Charlie Spiering
# 5652  CDC Disease Director: Low Number of U.S. Coron...   Dr. Susan Berry
#
#                 date                                            content  \
# ...

# %%
data_pipeline.articles.iloc[5]
# Out:
# 'President Trump’s Justice Department, led by his appointee Attorney General Bill Bar and recommended by Trump-nominated Judge Timothy Shea, announced today that they would be dropping the case against disgraced ex-National Security Advisor Michael Flynn. The move is an astonishing miscarriage of justice in the case against the treasonous Flynn, who pled guilty to lying to FBI investigators and cooperated with the Mueller probe before abruptly changing counsel and rescinding his guilty plea. Add your name to reject Trump & Republicans’ vile idea of sacrificing seniors’ lives to save the stock market! Putting the situation in extremely simple terms is House Intelligence Chairman Adam Schiff, who oversaw the Russia probe and the investigation into Michael Flynn over his unreported work as a paid agent for foreign powers and his secret communications with Russian agents prior to Trump’s inauguration. Flynn pled guilty to lying to the FBI about his illicit Russian contacts. His lies do n
# ...

# %%
data_pipeline.plot_word_counts()

# %%
data_pipeline.plot_top_ten_authors('breitbart','r')
# Out:
# author            source
# Charlie Spiering  breitbart    372
# Hannah Bleau      breitbart    340
# Pam Key           breitbart    260
# Joshua Caplan     breitbart    249
# Ian Hanchett      breitbart    207
# Joel B. Pollak    breitbart    169
# John Binder       breitbart    166
# Penny Starr       breitbart    144
# Trent Baker       breitbart    140
# Sean Moran        breitbart    131
# Name: title, dtype: int64

# %%
data_pipeline.plot_top_ten_authors('occupy_democrats','b')
# Out:
# author             source
# Colin Taylor       occupy_democrats    920
# Natalie Dickinson  occupy_democrats    768
# Vinnie Longobardo  occupy_democrats    633
# Grant Stern        occupy_democrats    515
# Brian Tyler Cohen  occupy_democrats    438
# Sheila Norton      occupy_democrats    371
# Rob Haffey         occupy_democrats    361
# Marisa Manfredo    occupy_democrats    245
# Peter Mellado      occupy_democrats    194
# Benjamin Locke     occupy_democrats    189
# Name: title, dtype: int64

# %%
data_pipeline.plot_article_dates()
